# %%
import os 
from dotenv import load_dotenv
load_dotenv()
import json
import requests
import re
import pandas as pd

# %%
def grade(issues):
    try:
        z= re.findall(r"grade:\d+",issues[0]["body"])
        z = str(z).split(":")
        z = z[1].split("']")
        return int(z[0])
    except:
        return None

# %%
def meme(issues):
    try:
        meme = re.findall(r"https:.*jpg|.*jpeg|.*png",issues[0]["body"])
        meme = str(meme).split("(")
        meme = meme[1].split("'")
        return meme[0]
    except:
        return None

# %%
def other_student(issues):
    try:
        return re.findall("@\w*-?\w+",issues[0]["body"])
    except:
        return None

# %%
def get_students(page, apiKey=os.getenv("API_GITHUB")): 
    
    """
    Get data from github using query parameters and passing a custom apikey header
    """
    
    # Compose the pulls url
    baseUrl = "https://api.github.com"
    endpoint = f"/repos/ironhack-datalabs/datamad0820/pulls/{page}"
    query_params = "?per_page=100&state=all"
    url = f"{baseUrl}{endpoint}{query_params}"
    
    
    # Compose the issues endpoint url
    baseUrl = "https://api.github.com"
    endpoint = f"/repos/ironhack-datalabs/datamad0820/issues/{page}/comments"
    query_params = "?per_page=100&state=all"
    url1 = f"{baseUrl}{endpoint}{query_params}"
    
    # Create the headers
    headers = {
        "Authorization": f"Bearer {apiKey}"
    }
    
    # make the request and get the response using HTTP GET verb 
    pull = requests.get(url, headers=headers)
    issue = requests.get(url1, headers=headers)
    pulls = pull.json()
    issues = issue.json()
    
    print(f"Request data to {pull.url} status_code:{pull.status_code}")
    print(f"Request data to {issue.url} status_code:{issue.status_code}")
    
    print(page)
        
    try:
        name = pulls["title"].split()[1:]
        return {"student_user": pulls["user"]["login"],
                "student_name":  " ".join(name),
                "student_id": pulls["user"]["id"],
                "pull_name": pulls["title"].split()[0],
                "pull_state": pulls["state"],
                "pull_created": pulls["created_at"],
                "pull_closed": pulls["closed_at"],
                "lab_number": pulls["number"],
                "grade": grade(issues),
                "meme": meme(issues),
                "other_student": other_student(issues)}
    except:
        return {"student_user": None,
                "student_name": None,
                "student_id": None,
                "pull_name": None,
                "pull_state": None,
                "pull_created": None,
                "pull_closed": None,
                "lab_number": None,
                "grade": None,
                "meme": None,
                "other_student": None}


get_students(541)
# Out:
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/541?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/541/comments?per_page=100&state=all status_code:200
# 541
# {'student_user': 'Diegon8',
#  'student_name': 'Diego Lopez-Puertas',
#  'student_id': 68472164,
#  'pull_name': '[lab-code-simplicity-efficiency]',
#  'pull_state': 'closed',
#  'pull_created': '2020-09-21T16:45:52Z',
#  'pull_closed': '2020-09-23T23:38:01Z',
#  'lab_number': 541,
#  'grade': 9,
#  'meme': None,
#  'other_student': []}

# %%
students = [get_students(i) for i in range(1,542)]
# Out:
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/1?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/1/comments?per_page=100&state=all status_code:200
# 1
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/2?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/2/comments?per_page=100&state=all status_code:200
# 2
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/3?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/3/comments?per_page=100&state=all status_code:200
# 3
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/4?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/4/comments?per_page=100&state=all status_code:200
# 4
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/5?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/5/comments?per_page=100&state=all status_code:200
# 5
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/6?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/6/comments?per_page=100&state=all status_code:200
# 6
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/7?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/7/comments?per_page=100&state=all status_code:200
# 7
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/8?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/8/comments?per_page=100&state=all status_code:200
# 8
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/9?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/9/comments?per_page=100&state=all status_code:200
# 9
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/10?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/10/comments?per_page=100&state=all status_code:200
# 10
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/11?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/11/comments?per_page=100&state=all status_code:200
# 11
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/12?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/12/comments?per_page=100&state=all status_code:200
# 12
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/13?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/13/comments?per_page=100&state=all status_code:200
# 13
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/14?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/14/comments?per_page=100&state=all status_code:200
# 14
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/15?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/15/comments?per_page=100&state=all status_code:200
# 15
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/16?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/16/comments?per_page=100&state=all status_code:200
# 16
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/17?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/17/comments?per_page=100&state=all status_code:200
# 17
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/18?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/18/comments?per_page=100&state=all status_code:200
# 18
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/19?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/19/comments?per_page=100&state=all status_code:200
# 19
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/20?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/20/comments?per_page=100&state=all status_code:200
# 20
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/21?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/21/comments?per_page=100&state=all status_code:200
# 21
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/22?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/22/comments?per_page=100&state=all status_code:200
# 22
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/23?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/23/comments?per_page=100&state=all status_code:200
# 23
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/24?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/24/comments?per_page=100&state=all status_code:200
# 24
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/25?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/25/comments?per_page=100&state=all status_code:200
# 25
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/26?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/26/comments?per_page=100&state=all status_code:200
# 26
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/27?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/27/comments?per_page=100&state=all status_code:200
# 27
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/28?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/28/comments?per_page=100&state=all status_code:200
# 28
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/29?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/29/comments?per_page=100&state=all status_code:200
# 29
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/30?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/30/comments?per_page=100&state=all status_code:200
# 30
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/31?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/31/comments?per_page=100&state=all status_code:200
# 31
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/32?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/32/comments?per_page=100&state=all status_code:200
# 32
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/33?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/33/comments?per_page=100&state=all status_code:200
# 33
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/34?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/34/comments?per_page=100&state=all status_code:200
# 34
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/35?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/35/comments?per_page=100&state=all status_code:200
# 35
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/36?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/36/comments?per_page=100&state=all status_code:200
# 36
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/37?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/37/comments?per_page=100&state=all status_code:200
# 37
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/38?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/38/comments?per_page=100&state=all status_code:200
# 38
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/39?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/39/comments?per_page=100&state=all status_code:200
# 39
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/40?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/40/comments?per_page=100&state=all status_code:200
# 40
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/41?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/41/comments?per_page=100&state=all status_code:200
# 41
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/42?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/42/comments?per_page=100&state=all status_code:200
# 42
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/43?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/43/comments?per_page=100&state=all status_code:200
# 43
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/44?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/44/comments?per_page=100&state=all status_code:200
# 44
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/45?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/45/comments?per_page=100&state=all status_code:200
# 45
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/46?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/46/comments?per_page=100&state=all status_code:200
# 46
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/47?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/47/comments?per_page=100&state=all status_code:200
# 47
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/48?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/48/comments?per_page=100&state=all status_code:200
# 48
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/49?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/49/comments?per_page=100&state=all status_code:200
# 49
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/50?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/50/comments?per_page=100&state=all status_code:200
# 50
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/51?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/51/comments?per_page=100&state=all status_code:200
# 51
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/52?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/52/comments?per_page=100&state=all status_code:200
# 52
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/53?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/53/comments?per_page=100&state=all status_code:200
# 53
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/54?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/54/comments?per_page=100&state=all status_code:200
# 54
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/55?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/55/comments?per_page=100&state=all status_code:200
# 55
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/56?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/56/comments?per_page=100&state=all status_code:200
# 56
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/57?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/57/comments?per_page=100&state=all status_code:200
# 57
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/58?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/58/comments?per_page=100&state=all status_code:200
# 58
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/59?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/59/comments?per_page=100&state=all status_code:200
# 59
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/60?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/60/comments?per_page=100&state=all status_code:200
# 60
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/61?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/61/comments?per_page=100&state=all status_code:200
# 61
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/62?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/62/comments?per_page=100&state=all status_code:200
# 62
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/63?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/63/comments?per_page=100&state=all status_code:200
# 63
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/64?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/64/comments?per_page=100&state=all status_code:200
# 64
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/65?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/65/comments?per_page=100&state=all status_code:200
# 65
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/66?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/66/comments?per_page=100&state=all status_code:200
# 66
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/67?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/67/comments?per_page=100&state=all status_code:200
# 67
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/68?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/68/comments?per_page=100&state=all status_code:200
# 68
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/69?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/69/comments?per_page=100&state=all status_code:200
# 69
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/70?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/70/comments?per_page=100&state=all status_code:200
# 70
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/71?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/71/comments?per_page=100&state=all status_code:200
# 71
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/72?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/72/comments?per_page=100&state=all status_code:200
# 72
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/73?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/73/comments?per_page=100&state=all status_code:200
# 73
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/74?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/74/comments?per_page=100&state=all status_code:200
# 74
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/75?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/75/comments?per_page=100&state=all status_code:200
# 75
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/76?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/76/comments?per_page=100&state=all status_code:200
# 76
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/77?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/77/comments?per_page=100&state=all status_code:200
# 77
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/78?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/78/comments?per_page=100&state=all status_code:200
# 78
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/79?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/79/comments?per_page=100&state=all status_code:200
# 79
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/80?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/80/comments?per_page=100&state=all status_code:200
# 80
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/81?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/81/comments?per_page=100&state=all status_code:200
# 81
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/82?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/82/comments?per_page=100&state=all status_code:200
# 82
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/83?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/83/comments?per_page=100&state=all status_code:200
# 83
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/84?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/84/comments?per_page=100&state=all status_code:200
# 84
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/85?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/85/comments?per_page=100&state=all status_code:200
# 85
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/86?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/86/comments?per_page=100&state=all status_code:200
# 86
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/87?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/87/comments?per_page=100&state=all status_code:200
# 87
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/88?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/88/comments?per_page=100&state=all status_code:200
# 88
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/89?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/89/comments?per_page=100&state=all status_code:200
# 89
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/90?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/90/comments?per_page=100&state=all status_code:200
# 90
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/91?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/91/comments?per_page=100&state=all status_code:200
# 91
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/92?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/92/comments?per_page=100&state=all status_code:200
# 92
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/93?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/93/comments?per_page=100&state=all status_code:200
# 93
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/94?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/94/comments?per_page=100&state=all status_code:200
# 94
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/95?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/95/comments?per_page=100&state=all status_code:200
# 95
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/96?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/96/comments?per_page=100&state=all status_code:200
# 96
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/97?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/97/comments?per_page=100&state=all status_code:200
# 97
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/98?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/98/comments?per_page=100&state=all status_code:200
# 98
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/99?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/99/comments?per_page=100&state=all status_code:200
# 99
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/100?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/100/comments?per_page=100&state=all status_code:200
# 100
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/101?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/101/comments?per_page=100&state=all status_code:200
# 101
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/102?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/102/comments?per_page=100&state=all status_code:200
# 102
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/103?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/103/comments?per_page=100&state=all status_code:200
# 103
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/104?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/104/comments?per_page=100&state=all status_code:200
# 104
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/105?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/105/comments?per_page=100&state=all status_code:200
# 105
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/106?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/106/comments?per_page=100&state=all status_code:200
# 106
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/107?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/107/comments?per_page=100&state=all status_code:200
# 107
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/108?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/108/comments?per_page=100&state=all status_code:200
# 108
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/109?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/109/comments?per_page=100&state=all status_code:200
# 109
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/110?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/110/comments?per_page=100&state=all status_code:200
# 110
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/111?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/111/comments?per_page=100&state=all status_code:200
# 111
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/112?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/112/comments?per_page=100&state=all status_code:200
# 112
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/113?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/113/comments?per_page=100&state=all status_code:200
# 113
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/114?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/114/comments?per_page=100&state=all status_code:200
# 114
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/115?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/115/comments?per_page=100&state=all status_code:200
# 115
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/116?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/116/comments?per_page=100&state=all status_code:200
# 116
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/117?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/117/comments?per_page=100&state=all status_code:200
# 117
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/118?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/118/comments?per_page=100&state=all status_code:200
# 118
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/119?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/119/comments?per_page=100&state=all status_code:200
# 119
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/120?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/120/comments?per_page=100&state=all status_code:200
# 120
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/121?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/121/comments?per_page=100&state=all status_code:200
# 121
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/122?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/122/comments?per_page=100&state=all status_code:200
# 122
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/123?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/123/comments?per_page=100&state=all status_code:200
# 123
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/124?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/124/comments?per_page=100&state=all status_code:200
# 124
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/125?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/125/comments?per_page=100&state=all status_code:200
# 125
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/126?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/126/comments?per_page=100&state=all status_code:200
# 126
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/127?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/127/comments?per_page=100&state=all status_code:200
# 127
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/128?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/128/comments?per_page=100&state=all status_code:200
# 128
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/129?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/129/comments?per_page=100&state=all status_code:200
# 129
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/130?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/130/comments?per_page=100&state=all status_code:200
# 130
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/131?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/131/comments?per_page=100&state=all status_code:200
# 131
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/132?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/132/comments?per_page=100&state=all status_code:200
# 132
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/133?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/133/comments?per_page=100&state=all status_code:200
# 133
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/134?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/134/comments?per_page=100&state=all status_code:200
# 134
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/135?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/135/comments?per_page=100&state=all status_code:200
# 135
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/136?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/136/comments?per_page=100&state=all status_code:200
# 136
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/137?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/137/comments?per_page=100&state=all status_code:200
# 137
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/138?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/138/comments?per_page=100&state=all status_code:200
# 138
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/139?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/139/comments?per_page=100&state=all status_code:200
# 139
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/140?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/140/comments?per_page=100&state=all status_code:200
# 140
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/141?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/141/comments?per_page=100&state=all status_code:200
# 141
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/142?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/142/comments?per_page=100&state=all status_code:200
# 142
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/143?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/143/comments?per_page=100&state=all status_code:200
# 143
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/144?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/144/comments?per_page=100&state=all status_code:200
# 144
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/145?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/145/comments?per_page=100&state=all status_code:200
# 145
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/146?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/146/comments?per_page=100&state=all status_code:200
# 146
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/147?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/147/comments?per_page=100&state=all status_code:200
# 147
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/148?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/148/comments?per_page=100&state=all status_code:200
# 148
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/149?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/149/comments?per_page=100&state=all status_code:200
# 149
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/150?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/150/comments?per_page=100&state=all status_code:200
# 150
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/151?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/151/comments?per_page=100&state=all status_code:200
# 151
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/152?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/152/comments?per_page=100&state=all status_code:200
# 152
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/153?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/153/comments?per_page=100&state=all status_code:200
# 153
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/154?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/154/comments?per_page=100&state=all status_code:200
# 154
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/155?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/155/comments?per_page=100&state=all status_code:200
# 155
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/156?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/156/comments?per_page=100&state=all status_code:200
# 156
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/157?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/157/comments?per_page=100&state=all status_code:200
# 157
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/158?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/158/comments?per_page=100&state=all status_code:200
# 158
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/159?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/159/comments?per_page=100&state=all status_code:200
# 159
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/160?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/160/comments?per_page=100&state=all status_code:200
# 160
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/161?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/161/comments?per_page=100&state=all status_code:200
# 161
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/162?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/162/comments?per_page=100&state=all status_code:200
# 162
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/163?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/163/comments?per_page=100&state=all status_code:200
# 163
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/164?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/164/comments?per_page=100&state=all status_code:200
# 164
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/165?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/165/comments?per_page=100&state=all status_code:200
# 165
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/166?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/166/comments?per_page=100&state=all status_code:200
# 166
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/167?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/167/comments?per_page=100&state=all status_code:200
# 167
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/168?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/168/comments?per_page=100&state=all status_code:200
# 168
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/169?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/169/comments?per_page=100&state=all status_code:200
# 169
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/170?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/170/comments?per_page=100&state=all status_code:200
# 170
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/171?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/171/comments?per_page=100&state=all status_code:200
# 171
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/172?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/172/comments?per_page=100&state=all status_code:200
# 172
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/173?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/173/comments?per_page=100&state=all status_code:200
# 173
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/174?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/174/comments?per_page=100&state=all status_code:200
# 174
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/175?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/175/comments?per_page=100&state=all status_code:200
# 175
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/176?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/176/comments?per_page=100&state=all status_code:200
# 176
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/177?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/177/comments?per_page=100&state=all status_code:200
# 177
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/178?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/178/comments?per_page=100&state=all status_code:200
# 178
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/179?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/179/comments?per_page=100&state=all status_code:200
# 179
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/180?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/180/comments?per_page=100&state=all status_code:200
# 180
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/181?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/181/comments?per_page=100&state=all status_code:200
# 181
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/182?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/182/comments?per_page=100&state=all status_code:200
# 182
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/183?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/183/comments?per_page=100&state=all status_code:200
# 183
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/184?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/184/comments?per_page=100&state=all status_code:200
# 184
# ...
# 480
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/481?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/481/comments?per_page=100&state=all status_code:200
# 481
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/482?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/482/comments?per_page=100&state=all status_code:200
# 482
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/483?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/483/comments?per_page=100&state=all status_code:200
# 483
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/484?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/484/comments?per_page=100&state=all status_code:200
# 484
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/485?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/485/comments?per_page=100&state=all status_code:200
# 485
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/486?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/486/comments?per_page=100&state=all status_code:200
# 486
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/487?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/487/comments?per_page=100&state=all status_code:200
# 487
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/488?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/488/comments?per_page=100&state=all status_code:200
# 488
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/489?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/489/comments?per_page=100&state=all status_code:200
# 489
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/490?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/490/comments?per_page=100&state=all status_code:200
# 490
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/491?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/491/comments?per_page=100&state=all status_code:200
# 491
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/492?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/492/comments?per_page=100&state=all status_code:200
# 492
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/493?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/493/comments?per_page=100&state=all status_code:200
# 493
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/494?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/494/comments?per_page=100&state=all status_code:200
# 494
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/495?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/495/comments?per_page=100&state=all status_code:200
# 495
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/496?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/496/comments?per_page=100&state=all status_code:200
# 496
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/497?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/497/comments?per_page=100&state=all status_code:200
# 497
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/498?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/498/comments?per_page=100&state=all status_code:200
# 498
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/499?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/499/comments?per_page=100&state=all status_code:200
# 499
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/500?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/500/comments?per_page=100&state=all status_code:200
# 500
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/501?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/501/comments?per_page=100&state=all status_code:200
# 501
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/502?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/502/comments?per_page=100&state=all status_code:200
# 502
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/503?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/503/comments?per_page=100&state=all status_code:200
# 503
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/504?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/504/comments?per_page=100&state=all status_code:200
# 504
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/505?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/505/comments?per_page=100&state=all status_code:200
# 505
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/506?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/506/comments?per_page=100&state=all status_code:200
# 506
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/507?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/507/comments?per_page=100&state=all status_code:200
# 507
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/508?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/508/comments?per_page=100&state=all status_code:200
# 508
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/509?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/509/comments?per_page=100&state=all status_code:200
# 509
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/510?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/510/comments?per_page=100&state=all status_code:200
# 510
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/511?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/511/comments?per_page=100&state=all status_code:200
# 511
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/512?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/512/comments?per_page=100&state=all status_code:200
# 512
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/513?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/513/comments?per_page=100&state=all status_code:200
# 513
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/514?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/514/comments?per_page=100&state=all status_code:200
# 514
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/515?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/515/comments?per_page=100&state=all status_code:200
# 515
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/516?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/516/comments?per_page=100&state=all status_code:200
# 516
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/517?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/517/comments?per_page=100&state=all status_code:200
# 517
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/518?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/518/comments?per_page=100&state=all status_code:200
# 518
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/519?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/519/comments?per_page=100&state=all status_code:200
# 519
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/520?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/520/comments?per_page=100&state=all status_code:200
# 520
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/521?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/521/comments?per_page=100&state=all status_code:200
# 521
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/522?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/522/comments?per_page=100&state=all status_code:200
# 522
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/523?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/523/comments?per_page=100&state=all status_code:200
# 523
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/524?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/524/comments?per_page=100&state=all status_code:200
# 524
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/525?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/525/comments?per_page=100&state=all status_code:200
# 525
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/526?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/526/comments?per_page=100&state=all status_code:200
# 526
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/527?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/527/comments?per_page=100&state=all status_code:200
# 527
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/528?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/528/comments?per_page=100&state=all status_code:200
# 528
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/529?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/529/comments?per_page=100&state=all status_code:200
# 529
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/530?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/530/comments?per_page=100&state=all status_code:200
# 530
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/531?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/531/comments?per_page=100&state=all status_code:200
# 531
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/532?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/532/comments?per_page=100&state=all status_code:200
# 532
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/533?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/533/comments?per_page=100&state=all status_code:200
# 533
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/534?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/534/comments?per_page=100&state=all status_code:200
# 534
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/535?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/535/comments?per_page=100&state=all status_code:200
# 535
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/536?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/536/comments?per_page=100&state=all status_code:200
# 536
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/537?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/537/comments?per_page=100&state=all status_code:200
# 537
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/538?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/538/comments?per_page=100&state=all status_code:200
# 538
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/539?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/539/comments?per_page=100&state=all status_code:200
# 539
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/540?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/540/comments?per_page=100&state=all status_code:200
# 540
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/pulls/541?per_page=100&state=all status_code:200
# Request data to https://api.github.com/repos/ironhack-datalabs/datamad0820/issues/541/comments?per_page=100&state=all status_code:200
# 541

# %%
students
# Out:
# [{'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-resolving-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T13:53:33Z',
#   'pull_closed': '2020-08-17T14:07:51Z',
#   'lab_number': 1,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T14:10:42Z',
#   'pull_closed': '2020-08-18T09:10:51Z',
#   'lab_number': 2,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90494122-7332f800-e143-11ea-8527-f257dcbb6101.jpeg',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T14:13:34Z',
#   'pull_closed': '2020-08-18T09:39:55Z',
#   'lab_number': 3,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90497587-8778f400-e147-11ea-8a36-9705614dbe14.png',
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T14:29:27Z',
#   'pull_closed': '2020-08-18T09:36:38Z',
#   'lab_number': 4,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90497110-ff92ea00-e146-11ea-9939-14202cda66cc.png',
#   'other_student': []},
#  {'student_user': 'CarlosSanzDGP',
#   'student_name': 'Carlos Sanz',
#   'student_id': 64006136,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T14:32:43Z',
#   'pull_closed': '2020-08-18T09:31:26Z',
#   'lab_number': 5,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90496566-48966e80-e146-11ea-83fb-cb3a6d9d9bff.png',
#   'other_student': []},
#  {'student_user': 'silviaherf',
#   'student_name': 'Silvia Hernandez',
#   'student_id': 65872238,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T14:42:18Z',
#   'pull_closed': '2020-08-18T09:23:30Z',
#   'lab_number': 6,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:03:15Z',
#   'pull_closed': '2020-08-18T08:52:54Z',
#   'lab_number': 7,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90491945-ea1ac180-e140-11ea-93f1-c04228d0ef8e.png',
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:03:22Z',
#   'pull_closed': '2020-08-18T09:53:04Z',
#   'lab_number': 8,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90498886-281be380-e149-11ea-926a-69065fe23401.png',
#   'other_student': []},
#  {'student_user': 'FDELTA',
#   'student_name': 'Fernando Delgado',
#   'student_id': 68896720,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:05:27Z',
#   'pull_closed': '2020-08-18T09:27:28Z',
#   'lab_number': 9,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90496162-c8700900-e145-11ea-804e-30e121ee9b95.jpeg',
#   'other_student': []},
#  {'student_user': 'marta-zavala',
#   'student_name': '- Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:09:19Z',
#   'pull_closed': '2020-08-18T10:01:50Z',
#   'lab_number': 10,
#   'grade': 0,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:11:22Z',
#   'pull_closed': '2020-08-18T09:14:13Z',
#   'lab_number': 11,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90494134-762de880-e143-11ea-90a9-19ef548d662a.png',
#   'other_student': []},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:14:49Z',
#   'pull_closed': '2020-08-18T09:43:45Z',
#   'lab_number': 12,
#   'grade': 0,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:15:42Z',
#   'pull_closed': '2020-08-18T09:37:04Z',
#   'lab_number': 13,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'Daniel García García',
#   'student_id': 11270478,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:17:58Z',
#   'pull_closed': '2020-08-18T09:41:30Z',
#   'lab_number': 14,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos Gonzalez Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:19:05Z',
#   'pull_closed': '2020-08-18T09:20:44Z',
#   'lab_number': 15,
#   'grade': 0,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:25:51Z',
#   'pull_closed': '2020-08-18T09:01:02Z',
#   'lab_number': 16,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90492928-02d7a700-e142-11ea-9629-87d9e5031b8e.png',
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:31:37Z',
#   'pull_closed': '2020-08-18T07:42:38Z',
#   'lab_number': 17,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:47:13Z',
#   'pull_closed': '2020-08-18T10:02:52Z',
#   'lab_number': 18,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Davidlazarog',
#   'student_name': 'David Lazaro',
#   'student_id': 68644448,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T15:50:21Z',
#   'pull_closed': '2020-08-18T10:05:27Z',
#   'lab_number': 19,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90500391-16d3d680-e14b-11ea-8280-1400017af9bd.jpeg',
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-resolving-git-conflits]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T16:31:48Z',
#   'pull_closed': '2020-08-18T09:59:02Z',
#   'lab_number': 20,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'resolving git conflicts',
#   'student_id': 68472164,
#   'pull_name': 'Lab',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T17:12:46Z',
#   'pull_closed': '2020-08-17T17:17:46Z',
#   'lab_number': 21,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T17:46:55Z',
#   'pull_closed': '2020-08-18T10:25:39Z',
#   'lab_number': 22,
#   'grade': 5,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90502309-e2154e80-e14d-11ea-8089-6cfab0e09782.jpeg',
#   'other_student': []},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'Paula Nuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T18:39:45Z',
#   'pull_closed': '2020-08-18T10:17:47Z',
#   'lab_number': 23,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90501576-dd9c6600-e14c-11ea-83e6-79c06173a98c.jpeg',
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-resolving-git-conflits]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-17T18:54:18Z',
#   'pull_closed': '2020-08-18T09:58:18Z',
#   'lab_number': 24,
#   'grade': 5,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90499642-12f38480-e14a-11ea-9da5-b353c910d9e4.jpeg',
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T07:42:04Z',
#   'pull_closed': '2020-08-18T09:48:03Z',
#   'lab_number': 25,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90498464-a926ab00-e148-11ea-8ff8-114bec60976c.png',
#   'other_student': []},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T11:36:07Z',
#   'pull_closed': '2020-08-18T13:30:56Z',
#   'lab_number': 26,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T13:57:56Z',
#   'pull_closed': '2020-08-19T15:16:24Z',
#   'lab_number': 27,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90653609-b07cb000-e23f-11ea-87ca-02a0221bfe4e.jpeg',
#   'other_student': []},
#  {'student_user': 'CarlosSanzDGP',
#   'student_name': 'Carlos Sanz',
#   'student_id': 64006136,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T14:00:43Z',
#   'pull_closed': '2020-08-19T14:02:59Z',
#   'lab_number': 28,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T14:07:12Z',
#   'pull_closed': '2020-08-19T10:54:48Z',
#   'lab_number': 29,
#   'grade': 7,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T14:11:54Z',
#   'pull_closed': '2020-08-19T14:23:49Z',
#   'lab_number': 30,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T15:26:28Z',
#   'pull_closed': '2020-08-19T14:10:35Z',
#   'lab_number': 31,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'marta-zavala',
#   'student_name': 'Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T15:28:03Z',
#   'pull_closed': '2020-08-19T15:16:44Z',
#   'lab_number': 32,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T15:33:06Z',
#   'pull_closed': '2020-08-19T11:56:59Z',
#   'lab_number': 33,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90631902-d09e7600-e223-11ea-8798-c48f094b4004.jpeg',
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos Gonzalez Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T17:08:59Z',
#   'pull_closed': '2020-08-19T13:57:31Z',
#   'lab_number': 34,
#   'grade': 6,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90623578-f5d8b780-e216-11ea-9be7-04ded70ee776.png',
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T17:35:51Z',
#   'pull_closed': '2020-08-19T14:46:51Z',
#   'lab_number': 35,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T17:38:40Z',
#   'pull_closed': '2020-08-19T14:28:17Z',
#   'lab_number': 36,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'FDELTA',
#   'student_name': 'Fernando Delgado',
#   'student_id': 68896720,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T17:40:14Z',
#   'pull_closed': '2020-08-19T13:59:21Z',
#   'lab_number': 37,
#   'grade': 19,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90644353-eb2d1b00-e234-11ea-91f1-b7a1788a0e51.jpeg',
#   'other_student': []},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T17:53:27Z',
#   'pull_closed': '2020-08-19T12:32:47Z',
#   'lab_number': 38,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90634952-d5195d80-e228-11ea-9932-d552eda275f1.jpeg',
#   'other_student': []},
#  {'student_user': 'silviaherf',
#   'student_name': 'Silvia Hernandez',
#   'student_id': 65872238,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T18:41:21Z',
#   'pull_closed': '2020-08-19T11:36:13Z',
#   'lab_number': 39,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90630216-ea8a8980-e220-11ea-8e7a-fb5b054ae685.jpeg',
#   'other_student': []},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T18:51:13Z',
#   'pull_closed': '2020-08-19T10:03:12Z',
#   'lab_number': 40,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90611927-a6d75600-e207-11ea-8bc2-66aa06c89ed2.png',
#   'other_student': []},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T19:01:32Z',
#   'pull_closed': '2020-08-19T11:48:26Z',
#   'lab_number': 41,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90631221-a0a2a300-e222-11ea-9bb3-6b952465a539.jpeg',
#   'other_student': []},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T19:03:05Z',
#   'pull_closed': '2020-08-19T10:02:45Z',
#   'lab_number': 42,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90614860-827d7880-e20b-11ea-96db-6b45bc87d49d.png',
#   'other_student': []},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'tuple set] Daniel Garcia Garcia',
#   'student_id': 11270478,
#   'pull_name': '[Lab',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T20:30:40Z',
#   'pull_closed': '2020-08-20T07:38:36Z',
#   'lab_number': 43,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90730735-e74ad880-e2c8-11ea-934a-430d7d28e24b.jpeg',
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T20:48:42Z',
#   'pull_closed': '2020-08-19T23:04:04Z',
#   'lab_number': 44,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Davidlazarog',
#   'student_name': 'David Lazaro',
#   'student_id': 68644448,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T21:06:29Z',
#   'pull_closed': '2020-08-20T08:52:14Z',
#   'lab_number': 45,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90748944-1bc39200-e2d3-11ea-8bae-4440a047c119.png',
#   'other_student': []},
#  {'student_user': 'Joycelili',
#   'student_name': 'tuple set dict] Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[Lab',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-18T21:55:57Z',
#   'pull_closed': '2020-08-19T12:23:06Z',
#   'lab_number': 46,
#   'grade': 7,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90634059-6c7db100-e227-11ea-9da5-5926d2283eb3.jpeg',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T05:10:34Z',
#   'pull_closed': '2020-08-19T14:13:17Z',
#   'lab_number': 47,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'PaulaNuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T06:52:37Z',
#   'pull_closed': '2020-08-19T10:37:15Z',
#   'lab_number': 48,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90624704-aa270d80-e218-11ea-808e-131b80c59ae0.jpeg',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T14:26:15Z',
#   'pull_closed': '2020-08-19T14:36:05Z',
#   'lab_number': 49,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'CarlosSanzDGP',
#   'student_name': 'Carlos Sanz',
#   'student_id': 64006136,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T14:48:03Z',
#   'pull_closed': '2020-08-19T14:53:08Z',
#   'lab_number': 50,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'DiegoCaulonga',
#   'student_name': 'Diego Caulonga',
#   'student_id': 69120593,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T14:52:59Z',
#   'pull_closed': '2020-08-20T09:02:31Z',
#   'lab_number': 51,
#   'grade': 7,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90750094-a062e000-e2d4-11ea-8b2f-6968b3f6f65d.jpeg',
#   'other_student': []},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:09:31Z',
#   'pull_closed': '2020-08-20T10:36:21Z',
#   'lab_number': 52,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'CarlosSanzDGP',
#   'student_name': 'Carlos Sanz',
#   'student_id': 64006136,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:15:28Z',
#   'pull_closed': '2020-08-20T08:52:44Z',
#   'lab_number': 53,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90749014-3269e900-e2d3-11ea-82ba-5e5eaafb4eb6.png',
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:22:23Z',
#   'pull_closed': '2020-08-19T15:46:20Z',
#   'lab_number': 54,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'marta-zavala',
#   'student_name': 'Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:23:48Z',
#   'pull_closed': '2020-08-20T13:11:10Z',
#   'lab_number': 55,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'laura290',
#   'student_name': 'Laura Larrad',
#   'student_id': 67266677,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:32:14Z',
#   'pull_closed': '2020-08-20T07:53:02Z',
#   'lab_number': 56,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'silviaherf',
#   'student_name': 'Silvia Hernandez',
#   'student_id': 65872238,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:50:48Z',
#   'pull_closed': '2020-08-20T09:45:59Z',
#   'lab_number': 57,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/90754805-ac51a080-e2da-11ea-8e0e-ac469af0e4fd.png',
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:51:52Z',
#   'pull_closed': '2020-08-20T09:13:19Z',
#   'lab_number': 58,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90751155-0ef46d80-e2d6-11ea-8734-5fd6985045e8.png',
#   'other_student': []},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T15:59:42Z',
#   'pull_closed': '2020-08-20T15:26:53Z',
#   'lab_number': 59,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T16:09:20Z',
#   'pull_closed': '2020-08-20T10:27:55Z',
#   'lab_number': 60,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T16:17:51Z',
#   'pull_closed': '2020-08-20T11:52:04Z',
#   'lab_number': 61,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Davidlazarog',
#   'student_name': 'David Lazaro',
#   'student_id': 68644448,
#   'pull_name': '[lab-generator-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T16:24:39Z',
#   'pull_closed': '2020-08-20T13:18:35Z',
#   'lab_number': 62,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T16:33:45Z',
#   'pull_closed': '2020-08-20T09:29:55Z',
#   'lab_number': 63,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90753084-73183100-e2d8-11ea-95a0-069c7b67933d.png',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T17:08:52Z',
#   'pull_closed': '2020-08-20T09:19:00Z',
#   'lab_number': 64,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'FDELTA',
#   'student_name': 'Fernando Delgado',
#   'student_id': 68896720,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T17:39:25Z',
#   'pull_closed': '2020-08-20T11:38:31Z',
#   'lab_number': 65,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'DiegoCaulonga',
#   'student_name': 'Diego Caulonga',
#   'student_id': 69120593,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T17:47:01Z',
#   'pull_closed': '2020-08-20T13:05:37Z',
#   'lab_number': 66,
#   'grade': 7,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T18:09:57Z',
#   'pull_closed': '2020-08-20T09:26:52Z',
#   'lab_number': 67,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90752719-06049b80-e2d8-11ea-954f-2e021dbe9f4f.png',
#   'other_student': []},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T18:21:27Z',
#   'pull_closed': '2020-08-20T11:05:33Z',
#   'lab_number': 68,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'Daniel Garcia Garcia',
#   'student_id': 11270478,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T18:26:56Z',
#   'pull_closed': '2020-08-20T14:34:22Z',
#   'lab_number': 69,
#   'grade': 7,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T20:30:56Z',
#   'pull_closed': '2020-08-20T08:08:41Z',
#   'lab_number': 70,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90733634-1d8a5700-e2cd-11ea-957f-219622c4fb80.png',
#   'other_student': []},
#  {'student_user': 'laura290',
#   'student_name': 'Laura Larrad',
#   'student_id': 67266677,
#   'pull_name': '[lab-generations-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T22:09:41Z',
#   'pull_closed': '2020-08-20T15:26:30Z',
#   'lab_number': 71,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T22:12:42Z',
#   'pull_closed': '2020-08-20T09:35:50Z',
#   'lab_number': 72,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Joycelili',
#   'student_name': 'Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T22:19:43Z',
#   'pull_closed': '2020-08-20T10:51:23Z',
#   'lab_number': 73,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[lab-generator-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T22:34:17Z',
#   'pull_closed': '2020-08-20T09:24:14Z',
#   'lab_number': 74,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90752309-82e34580-e2d7-11ea-9909-80e703d30c59.png',
#   'other_student': []},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-generator-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-19T22:38:46Z',
#   'pull_closed': '2020-08-20T08:20:26Z',
#   'lab_number': 75,
#   'grade': None,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90738555-b2da1b00-e2ce-11ea-9201-e8e392b81e9a.png',
#   'other_student': []},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'Paula Nuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T07:05:02Z',
#   'pull_closed': '2020-08-20T10:23:55Z',
#   'lab_number': 76,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos González-Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T08:58:38Z',
#   'pull_closed': '2020-08-20T15:35:00Z',
#   'lab_number': 77,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'marta-zavala',
#   'student_name': 'Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T13:19:01Z',
#   'pull_closed': '2020-08-20T15:13:05Z',
#   'lab_number': 78,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'CarlosSanzDGP',
#   'student_name': 'Carlos Sanz',
#   'student_id': 64006136,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T13:28:51Z',
#   'pull_closed': '2020-08-21T09:40:39Z',
#   'lab_number': 79,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90876559-1d5c8b00-e3a3-11ea-8f08-55b980896da0.png',
#   'other_student': []},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T14:03:46Z',
#   'pull_closed': '2020-08-20T15:25:58Z',
#   'lab_number': 80,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'laura290',
#   'student_name': 'Laura Larrad',
#   'student_id': 67266677,
#   'pull_name': '[lab-tuple-set-dict]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T14:54:34Z',
#   'pull_closed': '2020-08-20T15:18:52Z',
#   'lab_number': 81,
#   'grade': 7,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez]',
#   'student_id': 20644456,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T15:13:00Z',
#   'pull_closed': '2020-08-24T10:14:15Z',
#   'lab_number': 82,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos González Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-generating-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T15:39:10Z',
#   'pull_closed': '2020-08-20T15:45:21Z',
#   'lab_number': 83,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-errhand-listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T15:56:16Z',
#   'pull_closed': '2020-08-21T11:28:05Z',
#   'lab_number': 84,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90886131-1f7a1600-e3b2-11ea-8c2b-8ac1448cee22.png',
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T16:43:38Z',
#   'pull_closed': '2020-08-21T10:04:41Z',
#   'lab_number': 85,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90878883-67933b80-e3a6-11ea-8cf1-243950ffdb0e.png',
#   'other_student': []},
#  {'student_user': 'Joycelili',
#   'student_name': 'Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T16:51:40Z',
#   'pull_closed': '2020-08-24T10:37:23Z',
#   'lab_number': 86,
#   'grade': 7,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos González-Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T17:33:48Z',
#   'pull_closed': '2020-08-20T21:16:12Z',
#   'lab_number': 87,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90826594-041ff400-e33b-11ea-9ac9-e2230386ae44.png',
#   'other_student': []},
#  {'student_user': 'FDELTA',
#   'student_name': 'Fernando Delgado',
#   'student_id': 68896720,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T17:40:23Z',
#   'pull_closed': '2020-08-24T10:57:29Z',
#   'lab_number': 88,
#   'grade': 8,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T17:50:51Z',
#   'pull_closed': '2020-08-20T20:58:18Z',
#   'lab_number': 89,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90825001-98d52280-e338-11ea-9871-d40873997c20.png',
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T18:43:54Z',
#   'pull_closed': '2020-08-24T11:10:57Z',
#   'lab_number': 90,
#   'grade': 8,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T18:56:55Z',
#   'pull_closed': '2020-08-24T10:01:05Z',
#   'lab_number': 91,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T18:57:18Z',
#   'pull_closed': '2020-08-23T10:40:05Z',
#   'lab_number': 92,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Davidlazarog',
#   'student_name': 'David Lazaro',
#   'student_id': 68644448,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T18:57:23Z',
#   'pull_closed': '2020-08-24T11:27:22Z',
#   'lab_number': 93,
#   'grade': 8,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T19:02:19Z',
#   'pull_closed': '2020-08-20T20:24:18Z',
#   'lab_number': 94,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90821758-b8b61780-e333-11ea-9e4e-14132df49694.png',
#   'other_student': []},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T19:03:30Z',
#   'pull_closed': '2020-08-24T10:51:10Z',
#   'lab_number': 95,
#   'grade': 8,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'silviaherf',
#   'student_name': 'Silvia Hernandez',
#   'student_id': 65872238,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T19:21:30Z',
#   'pull_closed': '2020-08-21T15:05:54Z',
#   'lab_number': 96,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T19:46:41Z',
#   'pull_closed': '2020-08-20T20:12:27Z',
#   'lab_number': 97,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90820785-38db7d80-e332-11ea-85c9-0e8c757f565e.png',
#   'other_student': []},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'Daniel Garcia Garcia',
#   'student_id': 11270478,
#   'pull_name': '[lab-errhand-listcompo]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T21:18:40Z',
#   'pull_closed': '2020-08-24T11:40:59Z',
#   'lab_number': 98,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91040945-69136c80-e60f-11ea-811e-979cb55be5ae.png',
#   'other_student': []},
#  {'student_user': 'laura290',
#   'student_name': 'Laura Larrad',
#   'student_id': 67266677,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T22:27:45Z',
#   'pull_closed': '2020-08-23T10:54:16Z',
#   'lab_number': 99,
#   'grade': 8,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'DiegoCaulonga',
#   'student_name': 'Diego Caulonga',
#   'student_id': 69120593,
#   'pull_name': '[lab-errhand-listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T22:33:47Z',
#   'pull_closed': '2020-08-24T11:15:45Z',
#   'lab_number': 100,
#   'grade': 4,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[Lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-20T22:40:55Z',
#   'pull_closed': '2020-08-21T11:06:24Z',
#   'lab_number': 101,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90883950-163b7a00-e3af-11ea-8442-5847b3bec066.png',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-errhand_listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T06:41:08Z',
#   'pull_closed': '2020-08-21T10:54:14Z',
#   'lab_number': 102,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/49686519/90879505-4f6fec00-e3a7-11ea-94aa-c07ad48dedbd.png',
#   'other_student': []},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'Paula Nuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-errhand-listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T07:07:11Z',
#   'pull_closed': '2020-08-21T10:51:33Z',
#   'lab_number': 103,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T07:50:20Z',
#   'pull_closed': '2020-08-21T08:25:02Z',
#   'lab_number': 104,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-errhand-listcomp]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T11:01:41Z',
#   'pull_closed': '2020-08-21T14:50:56Z',
#   'lab_number': 105,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Joycelili',
#   'student_name': 'Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[lab-resolving-git-conflicts]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T14:20:31Z',
#   'pull_closed': '2020-08-24T08:33:42Z',
#   'lab_number': 106,
#   'grade': 10,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'marta-zavala',
#   'student_name': 'Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T14:26:09Z',
#   'pull_closed': '2020-08-24T10:05:22Z',
#   'lab_number': 107,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91030106-66108000-e5ff-11ea-8ec3-8fe7f45f4541.png',
#   'other_student': []},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T14:47:15Z',
#   'pull_closed': '2020-08-24T15:04:53Z',
#   'lab_number': 108,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91060993-e9e06180-e62b-11ea-905d-e062186bdbe7.png',
#   'other_student': []},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T15:21:41Z',
#   'pull_closed': '2020-08-25T10:03:56Z',
#   'lab_number': 109,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91161471-15665900-e6cb-11ea-8015-3c79267ce393.png',
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T15:24:24Z',
#   'pull_closed': '2020-08-24T10:20:25Z',
#   'lab_number': 110,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T16:05:43Z',
#   'pull_closed': '2020-08-24T10:30:36Z',
#   'lab_number': 111,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'Joycelili',
#   'student_name': 'Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T16:21:18Z',
#   'pull_closed': '2020-08-25T08:13:46Z',
#   'lab_number': 112,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T18:12:49Z',
#   'pull_closed': '2020-08-24T10:42:14Z',
#   'lab_number': 113,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-21T19:56:24Z',
#   'pull_closed': '2020-08-25T10:23:58Z',
#   'lab_number': 114,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91163427-d554a580-e6cd-11ea-8df9-9da080125db3.png',
#   'other_student': []},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-22T08:36:33Z',
#   'pull_closed': '2020-08-24T10:53:38Z',
#   'lab_number': 115,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'DiegoCaulonga',
#   'student_name': 'Diego Caulonga',
#   'student_id': 69120593,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-22T16:39:38Z',
#   'pull_closed': '2020-08-24T15:53:57Z',
#   'lab_number': 116,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91067079-c0770400-e632-11ea-921f-4033638947ea.png',
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-22T18:14:29Z',
#   'pull_closed': '2020-08-24T11:11:04Z',
#   'lab_number': 117,
#   'grade': 7,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-22T20:01:03Z',
#   'pull_closed': '2020-08-24T11:24:09Z',
#   'lab_number': 118,
#   'grade': 7,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'Paula Nuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-generators-functions]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-22T20:35:21Z',
#   'pull_closed': '2020-08-24T11:45:42Z',
#   'lab_number': 119,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'CarlosSanzDGP',
#   'student_name': 'Carlos Sanz',
#   'student_id': 64006136,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T09:28:30Z',
#   'pull_closed': '2020-08-24T11:29:07Z',
#   'lab_number': 120,
#   'grade': 7,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'laura290',
#   'student_name': 'Laura Larrad',
#   'student_id': 67266677,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T09:50:50Z',
#   'pull_closed': '2020-08-24T14:16:08Z',
#   'lab_number': 121,
#   'grade': 5,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T13:08:19Z',
#   'pull_closed': '2020-08-24T15:49:55Z',
#   'lab_number': 122,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91066333-e18b2500-e631-11ea-8056-f599c1c8a843.png',
#   'other_student': []},
#  {'student_user': 'silviaherf',
#   'student_name': 'Silvia Hernandez',
#   'student_id': 65872238,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T16:02:31Z',
#   'pull_closed': '2020-08-25T10:42:20Z',
#   'lab_number': 123,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91164712-d4247800-e6cf-11ea-9e7a-ae98cbd0b709.png',
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos González Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T17:41:12Z',
#   'pull_closed': '2020-08-24T16:04:37Z',
#   'lab_number': 124,
#   'grade': 6,
#   'meme': 'https://user-images.githubusercontent.com/52798316/91032230-f4860100-e601-11ea-9ceb-e4afd1db58be.png',
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T18:33:52Z',
#   'pull_closed': '2020-08-24T14:38:44Z',
#   'lab_number': 125,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91057998-3a55c000-e628-11ea-938c-0dc30f058b40.png',
#   'other_student': []},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'Garcia Daniel',
#   'student_id': 11270478,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T20:25:20Z',
#   'pull_closed': '2020-08-24T15:14:06Z',
#   'lab_number': 126,
#   'grade': 6,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91062159-a4706400-e62c-11ea-9536-07f76a2c5ce8.png',
#   'other_student': []},
#  {'student_user': 'Davidlazarog',
#   'student_name': 'David Lazaro',
#   'student_id': 68644448,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T20:54:18Z',
#   'pull_closed': '2020-08-24T15:43:19Z',
#   'lab_number': 127,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91065945-5f026580-e631-11ea-93d5-5fef5820d7f4.png',
#   'other_student': []},
#  {'student_user': 'FDELTA',
#   'student_name': 'Fernando Delgado',
#   'student_id': 68896720,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T21:53:56Z',
#   'pull_closed': '2020-08-25T10:28:35Z',
#   'lab_number': 128,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91164080-cc180880-e6ce-11ea-9856-58e7b8ac8c17.png',
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-data-vikings]',
#   'pull_state': 'closed',
#   'pull_created': '2020-08-23T22:17:09Z',
#   'pull_closed': '2020-08-24T16:20:35Z',
#   'lab_number': 129,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/57899051/91070032-798b0d80-e636-11ea-8275-2aca5a913ac9.png',
#   'other_student': []},
# ...
#   'student_id': 11270478,
#   'pull_name': '[lab-advance-querying-mongo]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-15T21:03:26Z',
#   'pull_closed': '2020-09-17T22:49:44Z',
#   'lab_number': 499,
#   'grade': 9,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-advance-querying-mongo]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T07:47:51Z',
#   'pull_closed': '2020-09-18T08:52:30Z',
#   'lab_number': 500,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93356303-4e639a80-f83f-11ea-8d61-65fe94209815.png',
#   'other_student': []},
#  {'student_user': 'Joycelili',
#   'student_name': 'Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T14:33:25Z',
#   'pull_closed': '2020-09-18T10:20:05Z',
#   'lab_number': 501,
#   'grade': 6,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T14:58:36Z',
#   'pull_closed': '2020-09-18T09:32:45Z',
#   'lab_number': 502,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T15:02:03Z',
#   'pull_closed': '2020-09-18T11:13:11Z',
#   'lab_number': 503,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'marta-zavala',
#   'student_name': 'Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T15:21:35Z',
#   'pull_closed': '2020-09-18T11:28:00Z',
#   'lab_number': 504,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93592078-d2d62a80-f9b1-11ea-9c21-7b7ab459a385.png',
#   'other_student': []},
#  {'student_user': 'Davidlazarog',
#   'student_name': 'David Lazaro',
#   'student_id': 68644448,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T15:41:27Z',
#   'pull_closed': None,
#   'lab_number': 505,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T15:42:02Z',
#   'pull_closed': '2020-09-21T11:41:07Z',
#   'lab_number': 506,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T16:50:10Z',
#   'pull_closed': None,
#   'lab_number': 507,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'silviaherf',
#   'student_name': 'Silvia Hernandez',
#   'student_id': 65872238,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T16:52:08Z',
#   'pull_closed': '2020-09-21T11:53:47Z',
#   'lab_number': 508,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T17:00:45Z',
#   'pull_closed': '2020-09-21T13:29:36Z',
#   'lab_number': 509,
#   'grade': 9,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T17:33:51Z',
#   'pull_closed': '2020-09-21T14:00:18Z',
#   'lab_number': 510,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'DiegoCaulonga',
#   'student_name': 'Diego Caulonga',
#   'student_id': 69120593,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T18:06:10Z',
#   'pull_closed': '2020-09-21T14:14:10Z',
#   'lab_number': 511,
#   'grade': 6,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T18:49:02Z',
#   'pull_closed': None,
#   'lab_number': 512,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'laura290',
#   'student_name': 'Laura Larrad',
#   'student_id': 67266677,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T18:53:22Z',
#   'pull_closed': '2020-09-21T14:22:55Z',
#   'lab_number': 513,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos González-Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T19:01:11Z',
#   'pull_closed': None,
#   'lab_number': 514,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'jorge-alamillos',
#   'student_name': 'Jorge Alamillos',
#   'student_id': 68734175,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T20:31:46Z',
#   'pull_closed': None,
#   'lab_number': 515,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'Daniel Garcia Garcia',
#   'student_id': 11270478,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T20:31:54Z',
#   'pull_closed': None,
#   'lab_number': 516,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-16T20:44:31Z',
#   'pull_closed': None,
#   'lab_number': 517,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-16T21:04:18Z',
#   'pull_closed': '2020-09-21T14:28:16Z',
#   'lab_number': 518,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez',
#   'student_id': 65113163,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T07:16:50Z',
#   'pull_closed': '2020-09-21T14:33:46Z',
#   'lab_number': 519,
#   'grade': 8,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'Paula Nuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T07:38:21Z',
#   'pull_closed': '2020-09-21T14:39:18Z',
#   'lab_number': 520,
#   'grade': 5,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93581456-7b2fc300-f9a1-11ea-89d2-a953d5c73e88.png',
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T08:16:25Z',
#   'pull_closed': None,
#   'lab_number': 521,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'FDELTA',
#   'student_name': 'David Lazaro y Fernando Delgado',
#   'student_id': 68896720,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T15:54:23Z',
#   'pull_closed': None,
#   'lab_number': 522,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'AnaMA96',
#   'student_name': 'Silvia Hernández y Ana Murillo',
#   'student_id': 60754286,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T16:08:34Z',
#   'pull_closed': None,
#   'lab_number': 523,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'miguelgimenezgimenez',
#   'student_name': 'Miguel Gimenez',
#   'student_id': 20644456,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T16:25:27Z',
#   'pull_closed': '2020-09-21T15:07:49Z',
#   'lab_number': 524,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93784146-e9d48100-fc2c-11ea-968e-d051c6496fe6.png',
#   'other_student': []},
#  {'student_user': 'VanessaMacC',
#   'student_name': 'Vanessa Machuca',
#   'student_id': 66739543,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T16:32:21Z',
#   'pull_closed': None,
#   'lab_number': 525,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'bmedm',
#   'student_name': 'Beatriz Medialdea',
#   'student_id': 66179117,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T16:33:40Z',
#   'pull_closed': '2020-09-21T15:11:56Z',
#   'lab_number': 526,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93784146-e9d48100-fc2c-11ea-968e-d051c6496fe6.png',
#   'other_student': []},
#  {'student_user': 'KevsDe',
#   'student_name': 'Kevin Careaga',
#   'student_id': 66921012,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T16:37:35Z',
#   'pull_closed': None,
#   'lab_number': 527,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'charliesket',
#   'student_name': 'Carlos González-Gordon',
#   'student_id': 68757683,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T16:37:47Z',
#   'pull_closed': None,
#   'lab_number': 528,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'Joycelili',
#   'student_name': 'Jorge Alamillos Joyce Acevedo',
#   'student_id': 66042132,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T16:49:51Z',
#   'pull_closed': None,
#   'lab_number': 529,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'marta-zavala',
#   'student_name': 'Marta Zavala',
#   'student_id': 62037527,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T16:56:03Z',
#   'pull_closed': '2020-09-21T15:15:03Z',
#   'lab_number': 530,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93784146-e9d48100-fc2c-11ea-968e-d051c6496fe6.png',
#   'other_student': []},
#  {'student_user': 'grundius1',
#   'student_name': 'Borja Llanos',
#   'student_id': 28903700,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T16:58:28Z',
#   'pull_closed': '2020-09-21T15:22:42Z',
#   'lab_number': 531,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93784146-e9d48100-fc2c-11ea-968e-d051c6496fe6.png',
#   'other_student': []},
#  {'student_user': 'jmena23',
#   'student_name': 'Juan Mena',
#   'student_id': 61025562,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T17:04:17Z',
#   'pull_closed': '2020-09-21T15:27:51Z',
#   'lab_number': 532,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93784146-e9d48100-fc2c-11ea-968e-d051c6496fe6.png',
#   'other_student': []},
#  {'student_user': 'DiegoCaulonga',
#   'student_name': 'Diego Caulonga',
#   'student_id': 69120593,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T17:07:26Z',
#   'pull_closed': '2020-09-21T15:33:50Z',
#   'lab_number': 533,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93784146-e9d48100-fc2c-11ea-968e-d051c6496fe6.png',
#   'other_student': []},
#  {'student_user': 'Daniel-GarciaGarcia',
#   'student_name': 'Daniel Garcia Garcia',
#   'student_id': 11270478,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T17:34:37Z',
#   'pull_closed': None,
#   'lab_number': 534,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'Jav1-Mart1nez',
#   'student_name': 'Javier Martínez',
#   'student_id': 68195145,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T17:51:22Z',
#   'pull_closed': None,
#   'lab_number': 535,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'rfminguez',
#   'student_name': 'Raul Fernandez',
#   'student_id': 5184420,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T18:47:19Z',
#   'pull_closed': '2020-09-21T15:42:28Z',
#   'lab_number': 536,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93789037-a597af80-fc31-11ea-9723-8d924548624d.png',
#   'other_student': []},
#  {'student_user': 'PaulaNuno',
#   'student_name': 'Laura Larrad y Paula Nuno',
#   'student_id': 56585597,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-17T18:56:47Z',
#   'pull_closed': '2020-09-21T15:47:18Z',
#   'lab_number': 537,
#   'grade': None,
#   'meme': None,
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-17T21:24:25Z',
#   'pull_closed': None,
#   'lab_number': 538,
#   'grade': None,
#   'meme': None,
#   'other_student': None},
#  {'student_user': 'IreneLopezLujan',
#   'student_name': 'Irene Lopez Luján',
#   'student_id': 65113163,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-18T06:25:41Z',
#   'pull_closed': '2020-09-21T15:54:26Z',
#   'lab_number': 539,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93790539-741fe380-fc33-11ea-92cf-6e8308b0bf8a.png',
#   'other_student': []},
#  {'student_user': 'gontzalm',
#   'student_name': 'Gontzal Monasterio',
#   'student_id': 63603386,
#   'pull_name': '[lab-tableau-data-visualization]',
#   'pull_state': 'closed',
#   'pull_created': '2020-09-18T10:35:42Z',
#   'pull_closed': '2020-09-21T16:01:22Z',
#   'lab_number': 540,
#   'grade': 10,
#   'meme': 'https://user-images.githubusercontent.com/52798316/93791370-6c147380-fc34-11ea-9357-4cc4fed170c3.png',
#   'other_student': []},
#  {'student_user': 'Diegon8',
#   'student_name': 'Diego Lopez-Puertas',
#   'student_id': 68472164,
#   'pull_name': '[lab-code-simplicity-efficiency]',
#   'pull_state': 'open',
#   'pull_created': '2020-09-21T16:45:52Z',
#   'pull_closed': None,
#   'lab_number': 541,
#   'grade': None,
#   'meme': None,
#   'other_student': None}]

# %%
studentsDF = pd.DataFrame(students)

# %%
studentsDF.to_json("outputs/students.json", orient="records")

# %%
# Importamos la base de datos a MongoDB
#mongoimport -d the_ranking -c students --jsonArray outputs/students.json
